# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitbehera1508/Some-ML-projects/blob/main/Gradientdescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d sarametawea/test-scores
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sarametawea/test-scores
# License(s): apache-2.0
# test-scores.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip test-scores.zip
# Out:
# Archive:  test-scores.zip
# replace test_scores.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test_scores.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

data =pd.read_csv('test_scores.csv')

# %%
data.head()
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     object
#  1   math    10 non-null     int64
#  2   cs      10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
data.tail()
# Out:
#      name  math  cs
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x= np.array(data['math'])
y= np.array(data['cs'])

# %%
x
# Out:
# array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67])

# %%
y
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73])

# %%
def gradient_descent(x,y):
  m_curr=b_curr=0
  iterations=10000
  n=len(x)
  learning_rate=0.000211
  cost_previous=0

  for i in range(iterations):
    y_predicted=m_curr*x + b_curr
    cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
    md=-(2/n)*sum(x*(y-y_predicted))
    bd=-(2/n)*sum(y-y_predicted)
    m_curr=m_curr-learning_rate*md
    b_curr=b_curr-learning_rate*bd
    if math.isclose(cost, cost_previous, rel_tol=1e-10):
            break
    cost_previous = cost
    print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

  return m_curr, b_curr

# %%
  m , b = gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.0415915955281856, b 0.231546991179955, cost 31.76729626003388 iteration 5000
# m 1.0413966516823774, b 0.23158502790837573, cost 31.76728821019309 iteration 5001
# m 1.0415900842744854, b 0.23162854397433286, cost 31.767280161351653 iteration 5002
# m 1.0413958605920817, b 0.23166658888911165, cost 31.767272113507165 iteration 5003
# m 1.0415885744118232, b 0.2317100928368539, cost 31.76726406665736 iteration 5004
# m 1.0413950682247186, b 0.2317481459004372, cost 31.767256020799984 iteration 5005
# m 1.0415870659352484, b 0.2317916377676397, cost 31.76724797593272 iteration 5006
# m 1.0413942745852232, b 0.23182969894261346, cost 31.767239932053286 iteration 5007
# m 1.04158555883983, b 0.23187317876681207, cost 31.76723188915947 iteration 5008
# m 1.0413934796785123, b 0.2319112480159012, cost 31.76722384724895 iteration 5009
# m 1.0415840531206546, b 0.23195471583449312, cost 31.76721580631956 iteration 5010
# ...

# %%
# prompt: draw a line using m and c using matplotlib

plt.scatter(x,y, color='red')
y_predicted = m*x + b
plt.plot(x, y_predicted, color='green')
plt.xlabel('Maths score')
plt.ylabel('CS score')
plt.title('Maths vs CS score')
plt.show()
